# %% [markdown]
# # 导入库

# %%
import efinance as ef

# %% [markdown]
# # 使用例子

# %% [markdown]
# ### 获取单只股票基本信息

# %%
stock_code = '600519'
ef.stock.get_base_info(stock_code)
# Out:
# 股票代码                   600519
# 股票名称                     贵州茅台
# 市盈率(动)e                 44.31
# 市净率                     14.11
# 所处行业                     酿酒行业
# 总市值           2473453468200.0
# 流通市值          2473453468200.0
# 板块编号                   BK0477
# ROE                      8.29
# 净利率                   54.1678
# 净利润        13954462085.610001
# 毛利率                   91.6763
# dtype: object

# %% [markdown]
# ### 获取多只股票基本信息

# %%
stock_codes = ['600519','300750']
ef.stock.get_base_info(stock_codes)
# Out:
# processing 600519: 100%|██████████| 2/2 [00:00<00:00,  9.03it/s]
#      股票代码  股票名称  市盈率(动)e    市净率  所处行业           总市值          流通市值    板块编号  \
# 0  300750  宁德时代   165.58  19.72  汽车行业  1.294416e+12  1.128090e+12  BK0481
# 1  600519  贵州茅台    44.31  14.11  酿酒行业  2.473453e+12  2.473453e+12  BK0477
#
#     ROE      净利率           净利润      毛利率
# 0  3.01  12.2289  1.954417e+09  27.2795
# 1  8.29  54.1678  1.395446e+10  91.6763

# %% [markdown]
# ### 获取单只股票日 k 数据

# %%
beg = '20200101' # 开始日期
end = '20210101'   # 结束日期
ef.stock.get_quote_history(stock_code,beg== beg,end=end)
# Out:
# processing 600519: 100%|██████████| 2/2 [00:00<00:00,  2.88it/s]
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27   -89.74   -89.53   -89.08   -90.07  406318
# 1     贵州茅台  600519  2001-08-28   -89.64   -89.27   -89.24   -89.72  129647
# 2     贵州茅台  600519  2001-08-29   -89.24   -89.36   -89.24   -89.42   53252
# 3     贵州茅台  600519  2001-08-30   -89.38   -89.22   -89.14   -89.44   48013
# 4     贵州茅台  600519  2001-08-31   -89.21   -89.24   -89.12   -89.28   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 4617  贵州茅台  600519  2020-12-25  1783.70  1810.71  1827.71  1780.71   23088
# 4618  贵州茅台  600519  2020-12-28  1807.31  1853.71  1869.51  1806.76   30080
# 4619  贵州茅台  600519  2020-12-29  1853.71  1847.71  1867.51  1835.71   22868
# 4620  贵州茅台  600519  2020-12-30  1850.71  1913.71  1913.71  1850.70   34452
# 4621  贵州茅台  600519  2020-12-31  1921.71  1978.71  1979.69  1919.71   38860
#
#                 成交额     振幅    涨跌幅    涨跌额    换手率
# 0     1410347000.00  -1.10   0.92   0.83  56.83
# 1      463463000.00  -0.54   0.29   0.26  18.13
# 2      194689000.00  -0.20  -0.10  -0.09   7.45
# 3      177558000.00  -0.34   0.16   0.14   6.72
# 4       86231000.00  -0.18  -0.02  -0.02   3.25
# ...             ...    ...    ...    ...    ...
# 4617  4218997632.00   2.60  -0.02  -0.34   0.18
# 4618  5616528640.00   3.47   2.37  43.00   0.24
# 4619  4275994832.00   1.72  -0.32  -6.00   0.18
# 4620  6604461312.00   3.41   3.57  66.00   0.27
# 4621  7682300672.00   3.13   3.40  65.00   0.31
#
# [4622 rows x 13 columns]

# %% [markdown]
# #### 获取单只股票的 5 分钟k线数据

# %%
import efinance as ef
stock_code = '600519'
beg = '20200101' # 开始日期
end = '20500101'   # 结束日期(最好比当前日期大，要不然可能没有数据)
klt = 5 # 指定获取的 k 线数据是 5 分钟的
ef.stock.get_quote_history(stock_code,beg = beg,end = end,klt=5)
# Out:
#       股票名称    股票代码                日期       开盘       收盘       最高       最低  \
# 0     贵州茅台  600519  2021-06-07 09:35  2245.71  2253.53  2259.71  2245.71
# 1     贵州茅台  600519  2021-06-07 09:40  2253.59  2242.74  2253.71  2238.68
# 2     贵州茅台  600519  2021-06-07 09:45  2243.16  2232.75  2243.16  2232.75
# 3     贵州茅台  600519  2021-06-07 09:50  2232.71  2239.70  2242.71  2227.02
# 4     贵州茅台  600519  2021-06-07 09:55  2236.99  2239.73  2244.71  2236.71
# ...    ...     ...               ...      ...      ...      ...      ...
# 1531  贵州茅台  600519  2021-07-21 14:40  1969.75  1969.72  1969.76  1966.66
# 1532  贵州茅台  600519  2021-07-21 14:45  1970.00  1970.08  1970.50  1969.74
# 1533  贵州茅台  600519  2021-07-21 14:50  1970.06  1969.98  1970.40  1969.72
# 1534  贵州茅台  600519  2021-07-21 14:55  1969.98  1967.80  1969.98  1966.70
# 1535  贵州茅台  600519  2021-07-21 15:00  1967.79  1969.00  1969.97  1967.79
#
#        成交量           成交额    振幅    涨跌幅     涨跌额   换手率
# 0     2693  611269846.00  0.63   0.96   21.32  0.02
# 1     1322  299747129.00  0.67  -0.48  -10.79  0.01
# 2      874  197345040.00  0.46  -0.45   -9.99  0.01
# 3     1119  252213116.00  0.70   0.31    6.95  0.01
# 4      765  172865660.00  0.36   0.00    0.03  0.01
# ...    ...           ...   ...    ...     ...   ...
# 1531   536  105466498.00  0.16   0.01    0.22  0.00
# 1532   307   60486491.00  0.04   0.02    0.36  0.00
# 1533   435   85624954.00  0.03  -0.01   -0.10  0.00
# 1534   660  129912941.00  0.17  -0.11   -2.18  0.01
# 1535   646  127183739.00  0.11   0.06    1.20  0.01
#
# [1536 rows x 13 columns]

# %% [markdown]
# ### 获取多只股票日 k 数据(得到以股票代码为 key，以 pandas.DataFrame 为值的字典)

# %%
beg = '20200101' # 开始日期
end = '20210101'   # 结束日期
stock_codes = ['600519','300750']
df_items = ef.stock.get_quote_history(stock_codes,beg== beg,end=end)
# Out:
# Processing: 600519: 100%|██████████| 2/2 [00:00<00:00,  5.66it/s]

# %%
type(df_items) # 查看类型
# Out:
# dict

# %%
df_items.keys()
# Out:
# dict_keys(['300750', '600519'])

# %%
df_items[stock_codes[0]] # 查看第一支股票的的 k 线数据
# Out:
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27   -89.74   -89.53   -89.08   -90.07  406318
# 1     贵州茅台  600519  2001-08-28   -89.64   -89.27   -89.24   -89.72  129647
# 2     贵州茅台  600519  2001-08-29   -89.24   -89.36   -89.24   -89.42   53252
# 3     贵州茅台  600519  2001-08-30   -89.38   -89.22   -89.14   -89.44   48013
# 4     贵州茅台  600519  2001-08-31   -89.21   -89.24   -89.12   -89.28   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 4617  贵州茅台  600519  2020-12-25  1783.70  1810.71  1827.71  1780.71   23088
# 4618  贵州茅台  600519  2020-12-28  1807.31  1853.71  1869.51  1806.76   30080
# 4619  贵州茅台  600519  2020-12-29  1853.71  1847.71  1867.51  1835.71   22868
# 4620  贵州茅台  600519  2020-12-30  1850.71  1913.71  1913.71  1850.70   34452
# 4621  贵州茅台  600519  2020-12-31  1921.71  1978.71  1979.69  1919.71   38860
#
#                 成交额     振幅    涨跌幅    涨跌额    换手率
# 0     1410347000.00  -1.10   0.92   0.83  56.83
# 1      463463000.00  -0.54   0.29   0.26  18.13
# 2      194689000.00  -0.20  -0.10  -0.09   7.45
# 3      177558000.00  -0.34   0.16   0.14   6.72
# 4       86231000.00  -0.18  -0.02  -0.02   3.25
# ...             ...    ...    ...    ...    ...
# 4617  4218997632.00   2.60  -0.02  -0.34   0.18
# 4618  5616528640.00   3.47   2.37  43.00   0.24
# 4619  4275994832.00   1.72  -0.32  -6.00   0.18
# 4620  6604461312.00   3.41   3.57  66.00   0.27
# 4621  7682300672.00   3.13   3.40  65.00   0.31
#
# [4622 rows x 13 columns]

# %% [markdown]
# # 更多使用例子详见文档 [efinance-docs](https://micro-sheep.github.io/efinance)
