# %% [markdown]
# # 导入库

# %%
import efinance as ef

# %% [markdown]
# # 使用例子

# %% [markdown]
# ### 获取单只股票基本信息

# %%
stock_code = '600519'
ef.stock.get_base_info(stock_code)
# Out:
# 股票代码                  600519
# 股票名称                    贵州茅台
# 市盈率(动)                 44.08
# 市净率                    13.44
# 所处行业                    酿酒行业
# 总市值          2173410623670.0
# 流通市值         2173410623670.0
# 板块编号                  BK0477
# ROE                     14.2
# 净利率                  53.3879
# 净利润       24653985551.580002
# 毛利率                  91.3784
# dtype: object

# %% [markdown]
# ### 获取多只股票基本信息

# %%
stock_codes = ['600519','300750']
ef.stock.get_base_info(stock_codes)
# Out:
# Processing 600519: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s]
#      股票代码  股票名称  市盈率(动)    市净率  所处行业           总市值          流通市值    板块编号  \
# 0  300750  宁德时代  158.82  18.91  汽车行业  1.241594e+12  1.082055e+12  BK0481
# 1  600519  贵州茅台   44.08  13.44  酿酒行业  2.173411e+12  2.173411e+12  BK0477
#
#      ROE      净利率           净利润      毛利率
# 0   3.01  12.2289  1.954417e+09  27.2795
# 1  14.20  53.3879  2.465399e+10  91.3784

# %% [markdown]
# ### 获取单只股票日 k 数据

# %%
beg = '20200101' # 开始日期
end = '20210101'   # 结束日期
ef.stock.get_quote_history(stock_code,beg== beg,end=end)
# Out:
# Processing 600519: 100%|██████████| 2/2 [00:01<00:00,  1.43it/s]
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27   -89.74   -89.53   -89.08   -90.07  406318
# 1     贵州茅台  600519  2001-08-28   -89.64   -89.27   -89.24   -89.72  129647
# 2     贵州茅台  600519  2001-08-29   -89.24   -89.36   -89.24   -89.42   53252
# 3     贵州茅台  600519  2001-08-30   -89.38   -89.22   -89.14   -89.44   48013
# 4     贵州茅台  600519  2001-08-31   -89.21   -89.24   -89.12   -89.28   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 4617  贵州茅台  600519  2020-12-25  1783.70  1810.71  1827.71  1780.71   23088
# 4618  贵州茅台  600519  2020-12-28  1807.31  1853.71  1869.51  1806.76   30080
# 4619  贵州茅台  600519  2020-12-29  1853.71  1847.71  1867.51  1835.71   22868
# 4620  贵州茅台  600519  2020-12-30  1850.71  1913.71  1913.71  1850.70   34452
# 4621  贵州茅台  600519  2020-12-31  1921.71  1978.71  1979.69  1919.71   38860
#
#                成交额    振幅   涨跌幅    涨跌额    换手率
# 0     1.410347e+09 -1.10  0.92   0.83  56.83
# 1     4.634630e+08 -0.54  0.29   0.26  18.13
# 2     1.946890e+08 -0.20 -0.10  -0.09   7.45
# 3     1.775580e+08 -0.34  0.16   0.14   6.72
# 4     8.623100e+07 -0.18 -0.02  -0.02   3.25
# ...            ...   ...   ...    ...    ...
# 4617  4.218998e+09  2.60 -0.02  -0.34   0.18
# 4618  5.616529e+09  3.47  2.37  43.00   0.24
# 4619  4.275995e+09  1.72 -0.32  -6.00   0.18
# 4620  6.604461e+09  3.41  3.57  66.00   0.27
# 4621  7.682301e+09  3.13  3.40  65.00   0.31
#
# [4622 rows x 13 columns]

# %% [markdown]
# #### 获取单只股票的 5 分钟k线数据

# %%
import efinance as ef
stock_code = '600519'
beg = '20200101' # 开始日期
end = '20500101'   # 结束日期(最好比当前日期大，要不然可能没有数据)
klt = 5 # 指定获取的 k 线数据是 5 分钟的
ef.stock.get_quote_history(stock_code,beg = beg,end = end,klt=5)
# Out:
#       股票名称    股票代码                日期       开盘       收盘       最高       最低  \
# 0     贵州茅台  600519  2021-06-21 09:35  2065.71  2075.71  2080.40  2065.71
# 1     贵州茅台  600519  2021-06-21 09:40  2074.71  2074.72  2080.36  2074.71
# 2     贵州茅台  600519  2021-06-21 09:45  2074.89  2078.60  2079.70  2066.31
# 3     贵州茅台  600519  2021-06-21 09:50  2075.71  2076.57  2077.71  2072.72
# 4     贵州茅台  600519  2021-06-21 09:55  2076.57  2068.70  2076.57  2065.71
# ...    ...     ...               ...      ...      ...      ...      ...
# 1489  贵州茅台  600519  2021-08-03 09:40  1727.99  1726.00  1736.00  1721.00
# 1490  贵州茅台  600519  2021-08-03 09:45  1725.99  1702.00  1731.79  1700.00
# 1491  贵州茅台  600519  2021-08-03 09:50  1702.00  1714.58  1714.58  1688.80
# 1492  贵州茅台  600519  2021-08-03 09:55  1714.87  1721.77  1725.35  1710.00
# 1493  贵州茅台  600519  2021-08-03 10:00  1722.00  1730.15  1731.76  1722.00
#
#        成交量          成交额    振幅   涨跌幅    涨跌额   换手率
# 0     2498  522688041.0  0.71  0.20   4.06  0.02
# 1     1559  327062303.0  0.27 -0.05  -0.99  0.01
# 2     1176  246014973.0  0.65  0.19   3.88  0.01
# 3      678  141981728.0  0.24 -0.10  -2.03  0.01
# 4      748  156270218.0  0.52 -0.38  -7.87  0.01
# ...    ...          ...   ...   ...    ...   ...
# 1489  2623  453274084.0  0.87 -0.08  -1.35  0.02
# 1490  3697  633087042.0  1.84 -1.39 -24.00  0.03
# 1491  3654  621392732.0  1.51  0.74  12.58  0.03
# 1492  1677  287967609.0  0.90  0.42   7.19  0.01
# 1493   793  136849083.0  0.57  0.49   8.38  0.01
#
# [1494 rows x 13 columns]

# %% [markdown]
# ### 获取多只股票日 k 数据(得到以股票代码为 key，以 pandas.DataFrame 为值的字典)

# %%
beg = '20200101' # 开始日期
end = '20210101'   # 结束日期
stock_codes = ['600519','300750']
df_items = ef.stock.get_quote_history(stock_codes,beg== beg,end=end)
# Out:
# Processing: 600519: 100%|██████████| 2/2 [00:01<00:00,  1.91it/s]

# %%
type(df_items) # 查看类型
# Out:
# dict

# %%
df_items.keys()
# Out:
# dict_keys(['300750', '600519'])

# %%
df_items[stock_codes[0]] # 查看第一支股票的的 k 线数据
# Out:
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27   -89.74   -89.53   -89.08   -90.07  406318
# 1     贵州茅台  600519  2001-08-28   -89.64   -89.27   -89.24   -89.72  129647
# 2     贵州茅台  600519  2001-08-29   -89.24   -89.36   -89.24   -89.42   53252
# 3     贵州茅台  600519  2001-08-30   -89.38   -89.22   -89.14   -89.44   48013
# 4     贵州茅台  600519  2001-08-31   -89.21   -89.24   -89.12   -89.28   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 4617  贵州茅台  600519  2020-12-25  1783.70  1810.71  1827.71  1780.71   23088
# 4618  贵州茅台  600519  2020-12-28  1807.31  1853.71  1869.51  1806.76   30080
# 4619  贵州茅台  600519  2020-12-29  1853.71  1847.71  1867.51  1835.71   22868
# 4620  贵州茅台  600519  2020-12-30  1850.71  1913.71  1913.71  1850.70   34452
# 4621  贵州茅台  600519  2020-12-31  1921.71  1978.71  1979.69  1919.71   38860
#
#                成交额    振幅   涨跌幅    涨跌额    换手率
# 0     1.410347e+09 -1.10  0.92   0.83  56.83
# 1     4.634630e+08 -0.54  0.29   0.26  18.13
# 2     1.946890e+08 -0.20 -0.10  -0.09   7.45
# 3     1.775580e+08 -0.34  0.16   0.14   6.72
# 4     8.623100e+07 -0.18 -0.02  -0.02   3.25
# ...            ...   ...   ...    ...    ...
# 4617  4.218998e+09  2.60 -0.02  -0.34   0.18
# 4618  5.616529e+09  3.47  2.37  43.00   0.24
# 4619  4.275995e+09  1.72 -0.32  -6.00   0.18
# 4620  6.604461e+09  3.41  3.57  66.00   0.27
# 4621  7.682301e+09  3.13  3.40  65.00   0.31
#
# [4622 rows x 13 columns]

# %% [markdown]
# # 更多使用例子详见文档 [efinance-docs](https://micro-sheep.github.io/efinance)
