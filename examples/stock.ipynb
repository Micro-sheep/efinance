# %% [markdown]
# # 导入库

# %%
import efinance as ef

# %% [markdown]
# # 使用例子

# %% [markdown]
# ### 获取单只股票基本信息

# %%
stock_code = '600519'
ef.stock.get_base_info(stock_code)
# Out:
# 股票代码                  600519
# 股票名称                    贵州茅台
# 市盈率(动)                 42.57
# 市净率                    12.98
# 所处行业                    酿酒行业
# 总市值          2099106523800.0
# 流通市值         2099106523800.0
# 板块编号                  BK0477
# ROE                     14.2
# 净利率                53.387935
# 净利润       24653985551.580002
# 毛利率                91.378421
# dtype: object

# %% [markdown]
# ### 获取多只股票基本信息

# %%
stock_codes = ['600519','300750']
ef.stock.get_base_info(stock_codes)
# Out:
# Processing 600519: 100%|██████████| 2/2 [00:00<00:00,  4.64it/s]
#      股票代码  股票名称  市盈率(动)    市净率  所处行业           总市值          流通市值    板块编号  \
# 0  300750  宁德时代  162.03  19.46  汽车行业  1.266701e+12  1.103936e+12  BK0481
# 1  600519  贵州茅台   42.57  12.98  酿酒行业  2.099107e+12  2.099107e+12  BK0477
#
#      ROE        净利率           净利润        毛利率
# 0   3.01  12.228872  1.954417e+09  27.279524
# 1  14.20  53.387935  2.465399e+10  91.378421

# %% [markdown]
# ### 获取单只股票日 k 数据

# %%
beg = '20200101' # 开始日期
end = '20210101'   # 结束日期
ef.stock.get_quote_history(stock_code,beg== beg,end=end)
# Out:
# Processing 600519: 100%|██████████| 2/2 [00:00<00:00,  2.47it/s]
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27   -89.74   -89.53   -89.08   -90.07  406318
# 1     贵州茅台  600519  2001-08-28   -89.64   -89.27   -89.24   -89.72  129647
# 2     贵州茅台  600519  2001-08-29   -89.24   -89.36   -89.24   -89.42   53252
# 3     贵州茅台  600519  2001-08-30   -89.38   -89.22   -89.14   -89.44   48013
# 4     贵州茅台  600519  2001-08-31   -89.21   -89.24   -89.12   -89.28   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 4617  贵州茅台  600519  2020-12-25  1783.70  1810.71  1827.71  1780.71   23088
# 4618  贵州茅台  600519  2020-12-28  1807.31  1853.71  1869.51  1806.76   30080
# 4619  贵州茅台  600519  2020-12-29  1853.71  1847.71  1867.51  1835.71   22868
# 4620  贵州茅台  600519  2020-12-30  1850.71  1913.71  1913.71  1850.70   34452
# 4621  贵州茅台  600519  2020-12-31  1921.71  1978.71  1979.69  1919.71   38860
#
#                成交额    振幅   涨跌幅    涨跌额    换手率
# 0     1.410347e+09 -1.10  0.92   0.83  56.83
# 1     4.634630e+08 -0.54  0.29   0.26  18.13
# 2     1.946890e+08 -0.20 -0.10  -0.09   7.45
# 3     1.775580e+08 -0.34  0.16   0.14   6.72
# 4     8.623100e+07 -0.18 -0.02  -0.02   3.25
# ...            ...   ...   ...    ...    ...
# 4617  4.218998e+09  2.60 -0.02  -0.34   0.18
# 4618  5.616529e+09  3.47  2.37  43.00   0.24
# 4619  4.275995e+09  1.72 -0.32  -6.00   0.18
# 4620  6.604461e+09  3.41  3.57  66.00   0.27
# 4621  7.682301e+09  3.13  3.40  65.00   0.31
#
# [4622 rows x 13 columns]

# %% [markdown]
# #### 获取单只股票的 5 分钟k线数据

# %%
import efinance as ef
stock_code = '600519'
beg = '20200101' # 开始日期
end = '20500101'   # 结束日期(最好比当前日期大，要不然可能没有数据)
klt = 5 # 指定获取的 k 线数据是 5 分钟的
ef.stock.get_quote_history(stock_code,beg = beg,end = end,klt=5)
# Out:
#       股票名称    股票代码                日期       开盘       收盘       最高       最低  \
# 0     贵州茅台  600519  2021-06-24 09:35  2020.72  2012.71  2025.71  2004.31
# 1     贵州茅台  600519  2021-06-24 09:40  2011.71  2004.32  2015.67  2004.32
# 2     贵州茅台  600519  2021-06-24 09:45  2004.71  2010.32  2010.48  2001.71
# 3     贵州茅台  600519  2021-06-24 09:50  2010.32  2008.72  2011.71  2007.96
# 4     贵州茅台  600519  2021-06-24 09:55  2008.21  2015.71  2015.91  2005.58
# ...    ...     ...               ...      ...      ...      ...      ...
# 1531  贵州茅台  600519  2021-08-06 14:40  1672.66  1672.39  1672.72  1672.39
# 1532  贵州茅台  600519  2021-08-06 14:45  1672.40  1671.88  1672.41  1671.88
# 1533  贵州茅台  600519  2021-08-06 14:50  1671.88  1669.51  1671.90  1669.00
# 1534  贵州茅台  600519  2021-08-06 14:55  1669.86  1671.39  1671.80  1669.51
# 1535  贵州茅台  600519  2021-08-06 15:00  1671.38  1671.00  1671.39  1671.00
#
#        成交量          成交额    振幅   涨跌幅   涨跌额   换手率
# 0     2645  538472344.0  1.06 -0.30 -6.00  0.02
# 1     1214  246514860.0  0.56 -0.42 -8.39  0.01
# 2     1383  279945449.0  0.44  0.30  6.00  0.01
# 3     1026  208333178.0  0.19 -0.08 -1.60  0.01
# 4      955  193800703.0  0.51  0.35  6.99  0.01
# ...    ...          ...   ...   ...   ...   ...
# 1531   391   65397397.0  0.02  0.00 -0.02  0.00
# 1532   587   98155779.0  0.03 -0.03 -0.51  0.00
# 1533   690  115244453.0  0.17 -0.14 -2.37  0.01
# 1534   960  160370824.0  0.14  0.11  1.88  0.01
# 1535  1370  228940541.0  0.02 -0.02 -0.39  0.01
#
# [1536 rows x 13 columns]

# %% [markdown]
# ### 获取多只股票日 k 数据(得到以股票代码为 key，以 pandas.DataFrame 为值的字典)

# %%
beg = '20200101' # 开始日期
end = '20210101'   # 结束日期
stock_codes = ['600519','300750']
df_items = ef.stock.get_quote_history(stock_codes,beg== beg,end=end)
# Out:
# Processing: 600519: 100%|██████████| 2/2 [00:00<00:00,  2.98it/s]

# %%
type(df_items) # 查看类型
# Out:
# dict

# %%
df_items.keys()
# Out:
# dict_keys(['300750', '600519'])

# %%
df_items[stock_codes[0]] # 查看第一支股票的的 k 线数据
# Out:
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27   -89.74   -89.53   -89.08   -90.07  406318
# 1     贵州茅台  600519  2001-08-28   -89.64   -89.27   -89.24   -89.72  129647
# 2     贵州茅台  600519  2001-08-29   -89.24   -89.36   -89.24   -89.42   53252
# 3     贵州茅台  600519  2001-08-30   -89.38   -89.22   -89.14   -89.44   48013
# 4     贵州茅台  600519  2001-08-31   -89.21   -89.24   -89.12   -89.28   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 4617  贵州茅台  600519  2020-12-25  1783.70  1810.71  1827.71  1780.71   23088
# 4618  贵州茅台  600519  2020-12-28  1807.31  1853.71  1869.51  1806.76   30080
# 4619  贵州茅台  600519  2020-12-29  1853.71  1847.71  1867.51  1835.71   22868
# 4620  贵州茅台  600519  2020-12-30  1850.71  1913.71  1913.71  1850.70   34452
# 4621  贵州茅台  600519  2020-12-31  1921.71  1978.71  1979.69  1919.71   38860
#
#                成交额    振幅   涨跌幅    涨跌额    换手率
# 0     1.410347e+09 -1.10  0.92   0.83  56.83
# 1     4.634630e+08 -0.54  0.29   0.26  18.13
# 2     1.946890e+08 -0.20 -0.10  -0.09   7.45
# 3     1.775580e+08 -0.34  0.16   0.14   6.72
# 4     8.623100e+07 -0.18 -0.02  -0.02   3.25
# ...            ...   ...   ...    ...    ...
# 4617  4.218998e+09  2.60 -0.02  -0.34   0.18
# 4618  5.616529e+09  3.47  2.37  43.00   0.24
# 4619  4.275995e+09  1.72 -0.32  -6.00   0.18
# 4620  6.604461e+09  3.41  3.57  66.00   0.27
# 4621  7.682301e+09  3.13  3.40  65.00   0.31
#
# [4622 rows x 13 columns]

# %% [markdown]
# # 更多使用例子详见文档 [efinance-docs](https://efinance.readthedocs.io/)
