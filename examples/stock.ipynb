# %% [markdown]
# # 导入库

# %%
import efinance as ef

# %% [markdown]
# # 使用例子

# %% [markdown]
# ### 获取单只股票基本信息

# %%
stock_code = '600519'
ef.stock.get_base_info(stock_code)
# Out:
# 股票代码                    600519
# 股票名称                      贵州茅台
# 市盈率(动)                   38.55
# 市盈率                      12.28
# 所处行业                      酿酒行业
# 总市值       2151728649642.000244
# 流通市值      2151728649642.000244
# 板块编号                    BK0477
# ROE                       8.29
# 净利率                    54.1678
# 净利润         13954462085.610001
# 毛利率                    91.6763
# dtype: object

# %% [markdown]
# ### 获取多只股票基本信息

# %%
stock_codes = ['600519','300750']
ef.stock.get_base_info(stock_codes)
# Out:
# processing 300750: 100%|██████████| 2/2 [00:00<00:00, 18.92it/s]
#      股票代码  股票名称  市盈率(动)    市盈率  所处行业           总市值          流通市值    板块编号  \
# 0  600519  贵州茅台   38.55  12.28  酿酒行业  2.151729e+12  2.151729e+12  BK0477
# 1  300750  宁德时代  147.47  17.56  汽车行业  1.152859e+12  1.004722e+12  BK0481
#
#     ROE      净利率           净利润      毛利率
# 0  8.29  54.1678  1.395446e+10  91.6763
# 1  3.01  12.2289  1.954417e+09  27.2795

# %% [markdown]
# ### 获取单只股票日 k 数据

# %%
beg = '20200101' # 开始日期
end = '20210101'   # 结束日期
ef.stock.get_quote_history(stock_code,beg== beg,end=end)
# Out:
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27   -89.74   -89.53   -89.08   -90.07  406318
# 1     贵州茅台  600519  2001-08-28   -89.64   -89.27   -89.24   -89.72  129647
# 2     贵州茅台  600519  2001-08-29   -89.24   -89.36   -89.24   -89.42   53252
# 3     贵州茅台  600519  2001-08-30   -89.38   -89.22   -89.14   -89.44   48013
# 4     贵州茅台  600519  2001-08-31   -89.21   -89.24   -89.12   -89.28   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 4617  贵州茅台  600519  2020-12-25  1783.70  1810.71  1827.71  1780.71   23088
# 4618  贵州茅台  600519  2020-12-28  1807.31  1853.71  1869.51  1806.76   30080
# 4619  贵州茅台  600519  2020-12-29  1853.71  1847.71  1867.51  1835.71   22868
# 4620  贵州茅台  600519  2020-12-30  1850.71  1913.71  1913.71  1850.70   34452
# 4621  贵州茅台  600519  2020-12-31  1921.71  1978.71  1979.69  1919.71   38860
#
#                 成交额     振幅    涨跌幅    涨跌额    换手率
# 0     1410347000.00  -1.10   0.92   0.83  56.83
# 1      463463000.00  -0.54   0.29   0.26  18.13
# 2      194689000.00  -0.20  -0.10  -0.09   7.45
# 3      177558000.00  -0.34   0.16   0.14   6.72
# 4       86231000.00  -0.18  -0.02  -0.02   3.25
# ...             ...    ...    ...    ...    ...
# 4617  4218997632.00   2.60  -0.02  -0.34   0.18
# 4618  5616528640.00   3.47   2.37  43.00   0.24
# 4619  4275994832.00   1.72  -0.32  -6.00   0.18
# 4620  6604461312.00   3.41   3.57  66.00   0.27
# 4621  7682300672.00   3.13   3.40  65.00   0.31
#
# [4622 rows x 13 columns]

# %% [markdown]
# #### 获取单只股票的 5 分钟k线数据

# %%
import efinance as ef
stock_code = '600519'
beg = '20200101' # 开始日期
end = '20500101'   # 结束日期(最好比当前日期大，要不然可能没有数据)
klt = 5 # 指定获取的 k 线数据是 5 分钟的
ef.stock.get_quote_history(stock_code,beg = beg,end = end,klt=5)
# Out:
#       股票名称    股票代码                日期       开盘       收盘       最高       最低  \
# 0     贵州茅台  600519  2021-06-11 09:35  2219.71  2206.89  2224.71  2205.71
# 1     贵州茅台  600519  2021-06-11 09:40  2207.81  2213.54  2213.54  2205.71
# 2     贵州茅台  600519  2021-06-11 09:45  2209.71  2210.04  2218.70  2208.41
# 3     贵州茅台  600519  2021-06-11 09:50  2208.81  2196.51  2208.81  2191.71
# 4     贵州茅台  600519  2021-06-11 09:55  2196.17  2191.71  2200.71  2191.71
# ...    ...     ...               ...      ...      ...      ...      ...
# 1531  贵州茅台  600519  2021-07-27 14:40  1727.00  1707.73  1727.00  1707.70
# 1532  贵州茅台  600519  2021-07-27 14:45  1709.99  1711.21  1715.00  1709.00
# 1533  贵州茅台  600519  2021-07-27 14:50  1711.33  1706.00  1718.00  1706.00
# 1534  贵州茅台  600519  2021-07-27 14:55  1705.30  1716.69  1720.00  1703.00
# 1535  贵州茅台  600519  2021-07-27 15:00  1717.68  1712.89  1717.69  1712.02
#
#        成交量           成交额    振幅    涨跌幅     涨跌额   换手率
# 0     2040  455811241.00  0.86  -0.55  -12.30  0.02
# 1     1163  259156426.00  0.35   0.30    6.65  0.01
# 2      941  209873911.00  0.46  -0.16   -3.50  0.01
# 3     1487  329918559.00  0.77  -0.61  -13.53  0.01
# 4     1105  244809221.00  0.41  -0.22   -4.80  0.01
# ...    ...           ...   ...    ...     ...   ...
# 1531  3964  680891621.00  1.12  -1.08  -18.60  0.03
# 1532  5330  911420399.00  0.35   0.20    3.48  0.04
# 1533  4016  687504607.00  0.70  -0.30   -5.21  0.03
# 1534  3591  614464441.00  1.00   0.63   10.69  0.03
# 1535  2066  353963231.00  0.33  -0.22   -3.80  0.02
#
# [1536 rows x 13 columns]

# %% [markdown]
# ### 获取多只股票日 k 数据(得到以股票代码为 key，以 pandas.DataFrame 为值的字典)

# %%
beg = '20200101' # 开始日期
end = '20210101'   # 结束日期
stock_codes = ['600519','300750']
df_items = ef.stock.get_quote_history(stock_codes,beg== beg,end=end)
# Out:
# Processing: 600519: 100%|██████████| 2/2 [00:00<00:00,  4.66it/s]

# %%
type(df_items) # 查看类型
# Out:
# dict

# %%
df_items.keys()
# Out:
# dict_keys(['300750', '600519'])

# %%
df_items[stock_codes[0]] # 查看第一支股票的的 k 线数据
# Out:
#       股票名称    股票代码          日期       开盘       收盘       最高       最低     成交量  \
# 0     贵州茅台  600519  2001-08-27   -89.74   -89.53   -89.08   -90.07  406318
# 1     贵州茅台  600519  2001-08-28   -89.64   -89.27   -89.24   -89.72  129647
# 2     贵州茅台  600519  2001-08-29   -89.24   -89.36   -89.24   -89.42   53252
# 3     贵州茅台  600519  2001-08-30   -89.38   -89.22   -89.14   -89.44   48013
# 4     贵州茅台  600519  2001-08-31   -89.21   -89.24   -89.12   -89.28   23231
# ...    ...     ...         ...      ...      ...      ...      ...     ...
# 4617  贵州茅台  600519  2020-12-25  1783.70  1810.71  1827.71  1780.71   23088
# 4618  贵州茅台  600519  2020-12-28  1807.31  1853.71  1869.51  1806.76   30080
# 4619  贵州茅台  600519  2020-12-29  1853.71  1847.71  1867.51  1835.71   22868
# 4620  贵州茅台  600519  2020-12-30  1850.71  1913.71  1913.71  1850.70   34452
# 4621  贵州茅台  600519  2020-12-31  1921.71  1978.71  1979.69  1919.71   38860
#
#                 成交额     振幅    涨跌幅    涨跌额    换手率
# 0     1410347000.00  -1.10   0.92   0.83  56.83
# 1      463463000.00  -0.54   0.29   0.26  18.13
# 2      194689000.00  -0.20  -0.10  -0.09   7.45
# 3      177558000.00  -0.34   0.16   0.14   6.72
# 4       86231000.00  -0.18  -0.02  -0.02   3.25
# ...             ...    ...    ...    ...    ...
# 4617  4218997632.00   2.60  -0.02  -0.34   0.18
# 4618  5616528640.00   3.47   2.37  43.00   0.24
# 4619  4275994832.00   1.72  -0.32  -6.00   0.18
# 4620  6604461312.00   3.41   3.57  66.00   0.27
# 4621  7682300672.00   3.13   3.40  65.00   0.31
#
# [4622 rows x 13 columns]

# %% [markdown]
# # 更多使用例子详见文档 [efinance-docs](https://micro-sheep.github.io/efinance)
