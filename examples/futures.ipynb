# %% [markdown]
# # 导入库

# %%
import efinance as ef

# %% [markdown]
# # 使用例子

# %% [markdown]
# ### 获取四大交易所期货信息

# %%
ef.futures.get_futures_base_info()
# Out:
#        期货代码      期货名称       secid 归属交易所
# 0     j2207    焦炭2207   114.j2207   大商所
# 1    jd2108    鸡蛋2108  114.jd2108   大商所
# 2        im     铁矿石主力      114.im   大商所
# 3     i2109   铁矿石2109   114.i2109   大商所
# 4    ru2108    橡胶2108  113.ru2108   上期所
# ..      ...       ...         ...   ...
# 782  rb2204   螺纹钢2204  113.rb2204   上期所
# 783  hc2203  热轧卷板2203  113.hc2203   上期所
# 784  jm2206    焦煤2206  114.jm2206   大商所
# 785  eg2206   乙二醇2206  114.eg2206   大商所
# 786  hc2108  热轧卷板2108  113.hc2108   上期所
#
# [787 rows x 4 columns]

# %% [markdown]
# ### 获取单个期货 k 线数据

# %%
secid = '115.ZCM'
ef.futures.get_quote_history(secid)
# Out:
#               日期     开盘     收盘     最高     最低     成交量           成交额    振幅  \
# 0     2015-05-18  440.0  437.6  440.2  437.6      64  2.806300e+06  0.00
# 1     2015-05-19  436.0  437.0  437.6  436.0       6  2.621000e+05  0.36
# 2     2015-05-20  436.8  435.8  437.0  434.8       8  3.487500e+05  0.50
# 3     2015-05-21  438.0  443.2  446.8  437.8      37  1.631850e+06  2.06
# 4     2015-05-22  439.2  441.4  443.8  439.2      34  1.502500e+06  1.04
# ...          ...    ...    ...    ...    ...     ...           ...   ...
# 1510  2021-07-28  892.4  902.4  909.6  890.4   89853  8.086770e+09  2.14
# 1511  2021-07-29  902.6  918.6  919.0  900.4   83106  7.562646e+09  2.07
# 1512  2021-07-30  918.6  927.2  943.0  906.2  129862  1.202003e+10  4.04
# 1513  2021-08-02  898.0  865.2  898.0  852.4  175701  1.532464e+10  4.93
# 1514  2021-08-03  865.4  868.4  876.2  864.0   34949  3.038466e+09  1.40
#
#        涨跌幅   涨跌额  换手率
# 0     0.00   0.0  0.0
# 1    -0.32  -1.4  0.0
# 2    -0.23  -1.0  0.0
# 3     1.65   7.2  0.0
# 4     0.09   0.4  0.0
# ...    ...   ...  ...
# 1510  0.38   3.4  0.0
# 1511  2.07  18.6  0.0
# 1512  1.89  17.2  0.0
# 1513 -6.53 -60.4  0.0
# 1514 -0.44  -3.8  0.0
#
# [1515 rows x 11 columns]

# %% [markdown]
# ### 获取多个期货历史 k 线数据

# %%
secids = ['115.ZCM','115.ZC109']
ef.futures.get_quote_history(secids)
# Out:
# Processing: 115.ZCM: 100%|██████████| 2/2 [00:00<00:00,  3.69it/s]
# {'115.ZC109':              日期     开盘     收盘     最高     最低     成交量           成交额    振幅   涨跌幅  \
#  0    2020-09-09  551.2  551.2  551.2  551.2       2  1.102400e+05  0.00  0.00
#  1    2020-09-10  548.6  545.0  549.8  545.0       6  3.289200e+05  0.87 -1.12
#  2    2020-09-11  545.0  544.2  548.4  543.0       7  3.815000e+05  0.99 -0.73
#  3    2020-09-14  546.0  550.4  550.4  546.0       7  3.843000e+05  0.81  0.99
#  4    2020-09-15  549.0  551.2  551.6  549.0      14  7.705600e+05  0.47  0.40
#  ..          ...    ...    ...    ...    ...     ...           ...   ...   ...
#  213  2021-07-28  892.4  902.4  909.6  890.4   89853  8.086770e+09  2.14  0.38
#  214  2021-07-29  902.6  918.6  919.0  900.4   83106  7.562646e+09  2.07  2.07
#  215  2021-07-30  918.6  927.2  943.0  906.2  129862  1.202003e+10  4.04  1.89
#  216  2021-08-02  898.0  865.2  898.0  852.4  175701  1.532464e+10  4.93 -6.53
#  217  2021-08-03  865.4  868.4  876.2  864.0   34949  3.038466e+09  1.40 -0.44
#
#        涨跌额  换手率
#  0     0.0  0.0
#  1    -6.2  0.0
#  2    -4.0  0.0
#  3     5.4  0.0
#  4     2.2  0.0
#  ..    ...  ...
#  213   3.4  0.0
#  214  18.6  0.0
#  215  17.2  0.0
#  216 -60.4  0.0
#  217  -3.8  0.0
#
#  [218 rows x 11 columns],
#  '115.ZCM':               日期     开盘     收盘     最高     最低     成交量           成交额    振幅  \
#  0     2015-05-18  440.0  437.6  440.2  437.6      64  2.806300e+06  0.00
#  1     2015-05-19  436.0  437.0  437.6  436.0       6  2.621000e+05  0.36
#  2     2015-05-20  436.8  435.8  437.0  434.8       8  3.487500e+05  0.50
#  3     2015-05-21  438.0  443.2  446.8  437.8      37  1.631850e+06  2.06
#  4     2015-05-22  439.2  441.4  443.8  439.2      34  1.502500e+06  1.04
#  ...          ...    ...    ...    ...    ...     ...           ...   ...
#  1510  2021-07-28  892.4  902.4  909.6  890.4   89853  8.086770e+09  2.14
#  1511  2021-07-29  902.6  918.6  919.0  900.4   83106  7.562646e+09  2.07
#  1512  2021-07-30  918.6  927.2  943.0  906.2  129862  1.202003e+10  4.04
#  1513  2021-08-02  898.0  865.2  898.0  852.4  175701  1.532464e+10  4.93
#  1514  2021-08-03  865.4  868.4  876.2  864.0   34949  3.038466e+09  1.40
#
#         涨跌幅   涨跌额  换手率
#  0     0.00   0.0  0.0
#  1    -0.32  -1.4  0.0
#  2    -0.23  -1.0  0.0
#  3     1.65   7.2  0.0
#  4     0.09   0.4  0.0
#  ...    ...   ...  ...
#  1510  0.38   3.4  0.0
#  1511  2.07  18.6  0.0
#  1512  1.89  17.2  0.0
#  1513 -6.53 -60.4  0.0
#  1514 -0.44  -3.8  0.0
#
#  [1515 rows x 11 columns]}

# %% [markdown]
# # 更多使用例子详见文档 [efinance-docs](https://micro-sheep.github.io/efinance)
