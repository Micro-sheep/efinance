# %% [markdown]
# # 导入库

# %%
import efinance as ef

# %% [markdown]
# # 使用例子

# %% [markdown]
# ### 获取四大交易所期货信息

# %%
ef.futures.get_futures_base_info()
# Out:
#        期货代码     期货名称       secid 归属交易所
# 0    ss2202  不锈钢2202  113.ss2202   上期所
# 1       nim     沪镍主力     113.nim   上期所
# 2    ni2108   沪镍2108  113.ni2108   上期所
# 3       nis    沪镍次主力     113.nis   上期所
# 4    ni2109   沪镍2109  113.ni2109   上期所
# ..      ...      ...         ...   ...
# 781     FGS    玻璃次主力     115.FGS   郑商所
# 782   FG109    玻璃109   115.FG109   郑商所
# 783   FG203    玻璃203   115.FG203   郑商所
# 784   FG202    玻璃202   115.FG202   郑商所
# 785   FG108    玻璃108   115.FG108   郑商所
#
# [786 rows x 4 columns]

# %% [markdown]
# ### 获取单个期货 k 线数据

# %%
secid = '115.ZCM'
ef.futures.get_quote_history(secid)
# Out:
#               日期     开盘     收盘     最高     最低     成交量            成交额    振幅  \
# 0     2015-05-18  440.0  437.6  440.2  437.6      64      2806300.0  0.00
# 1     2015-05-19  436.0  437.0  437.6  436.0       6       262100.0  0.36
# 2     2015-05-20  436.8  435.8  437.0  434.8       8       348750.0  0.50
# 3     2015-05-21  438.0  443.2  446.8  437.8      37      1631850.0  2.06
# 4     2015-05-22  439.2  441.4  443.8  439.2      34      1502500.0  1.04
# ...          ...    ...    ...    ...    ...     ...            ...   ...
# 1504  2021-07-20  909.8  918.4  929.0  903.6  131953  12081616640.0  2.80
# 1505  2021-07-21  920.0  911.6  928.0  901.6  103848   9508322816.0  2.88
# 1506  2021-07-22  915.2  908.8  918.2  897.6   93943   8545055232.0  2.25
# 1507  2021-07-23  910.0  911.2  924.2  898.0  110897  10093844992.0  2.88
# 1508  2021-07-26  905.2  901.6  908.4  885.0   74919   6706748928.0  2.57
#
#         涨跌幅   涨跌额   换手率
# 0      0.00   0.0  0.00
# 1     -0.32  -1.4  0.00
# 2     -0.23  -1.0  0.00
# 3      1.65   7.2  0.00
# 4      0.09   0.4  0.00
# ...     ...   ...   ...
# 1504   1.30  11.8  0.00
# 1505  -0.44  -4.0  0.00
# 1506  -0.74  -6.8  0.00
# 1507   0.18   1.6  0.00
# 1508  -0.94  -8.6  0.00
#
# [1509 rows x 11 columns]

# %% [markdown]
# ### 获取多个期货历史 k 线数据

# %%
secids = ['115.ZCM','115.ZC109']
ef.futures.get_quote_history(secids)
# Out:
# Processing: 115.ZCM: 100%|██████████| 2/2 [00:00<00:00,  6.15it/s]
# {'115.ZC109':              日期     开盘     收盘     最高     最低     成交量            成交额    振幅  \
#  0    2020-09-09  551.2  551.2  551.2  551.2       2       110240.0  0.00
#  1    2020-09-10  548.6  545.0  549.8  545.0       6       328920.0  0.87
#  2    2020-09-11  545.0  544.2  548.4  543.0       7       381500.0  0.99
#  3    2020-09-14  546.0  550.4  550.4  546.0       7       384300.0  0.81
#  4    2020-09-15  549.0  551.2  551.6  549.0      14       770560.0  0.47
#  ..          ...    ...    ...    ...    ...     ...            ...   ...
#  207  2021-07-20  909.8  918.4  929.0  903.6  131953  12081616640.0  2.80
#  208  2021-07-21  920.0  911.6  928.0  901.6  103848   9508322816.0  2.88
#  209  2021-07-22  915.2  908.8  918.2  897.6   93943   8545055232.0  2.25
#  210  2021-07-23  910.0  911.2  924.2  898.0  110897  10093844992.0  2.88
#  211  2021-07-26  905.2  901.6  908.4  885.0   74919   6706748928.0  2.57
#
#         涨跌幅   涨跌额   换手率
#  0     0.00   0.0  0.00
#  1    -1.12  -6.2  0.00
#  2    -0.73  -4.0  0.00
#  3     0.99   5.4  0.00
#  4     0.40   2.2  0.00
#  ..     ...   ...   ...
#  207   1.30  11.8  0.00
#  208  -0.44  -4.0  0.00
#  209  -0.74  -6.8  0.00
#  210   0.18   1.6  0.00
#  211  -0.94  -8.6  0.00
#
#  [212 rows x 11 columns],
#  '115.ZCM':               日期     开盘     收盘     最高     最低     成交量            成交额    振幅  \
#  0     2015-05-18  440.0  437.6  440.2  437.6      64      2806300.0  0.00
#  1     2015-05-19  436.0  437.0  437.6  436.0       6       262100.0  0.36
#  2     2015-05-20  436.8  435.8  437.0  434.8       8       348750.0  0.50
#  3     2015-05-21  438.0  443.2  446.8  437.8      37      1631850.0  2.06
#  4     2015-05-22  439.2  441.4  443.8  439.2      34      1502500.0  1.04
#  ...          ...    ...    ...    ...    ...     ...            ...   ...
#  1504  2021-07-20  909.8  918.4  929.0  903.6  131953  12081616640.0  2.80
#  1505  2021-07-21  920.0  911.6  928.0  901.6  103848   9508322816.0  2.88
#  1506  2021-07-22  915.2  908.8  918.2  897.6   93943   8545055232.0  2.25
#  1507  2021-07-23  910.0  911.2  924.2  898.0  110897  10093844992.0  2.88
#  1508  2021-07-26  905.2  901.6  908.4  885.0   74919   6706748928.0  2.57
#
#          涨跌幅   涨跌额   换手率
#  0      0.00   0.0  0.00
#  1     -0.32  -1.4  0.00
#  2     -0.23  -1.0  0.00
#  3      1.65   7.2  0.00
#  4      0.09   0.4  0.00
#  ...     ...   ...   ...
#  1504   1.30  11.8  0.00
#  1505  -0.44  -4.0  0.00
#  1506  -0.74  -6.8  0.00
#  1507   0.18   1.6  0.00
#  1508  -0.94  -8.6  0.00
#
#  [1509 rows x 11 columns]}

# %% [markdown]
# # 更多使用例子详见文档 [efinance-docs](https://micro-sheep.github.io/efinance)
