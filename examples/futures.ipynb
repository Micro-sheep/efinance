# %% [markdown]
# # 导入库

# %%
import efinance as ef

# %% [markdown]
# # 使用例子

# %% [markdown]
# ### 获取四大交易所期货信息

# %%
ef.futures.get_futures_base_info()
# Out:
#        期货代码     期货名称       secid 归属交易所
# 0     SA109    纯碱109   115.SA109   郑商所
# 1     p2202  棕榈油2202   114.p2202   大商所
# 2        ps   棕榈油次主力      114.ps   大商所
# 3     p2201  棕榈油2201   114.p2201   大商所
# 4     SA203    纯碱203   115.SA203   郑商所
# ..      ...      ...         ...   ...
# 782  eg2112  乙二醇2112  114.eg2112   大商所
# 783  eg2110  乙二醇2110  114.eg2110   大商所
# 784     egm    乙二醇主力     114.egm   大商所
# 785  eg2109  乙二醇2109  114.eg2109   大商所
# 786  eb2207  苯乙烯2207  114.eb2207   大商所
#
# [787 rows x 4 columns]

# %% [markdown]
# ### 获取单个期货 k 线数据

# %%
secid = '115.ZCM'
ef.futures.get_quote_history(secid)
# Out:
#        期货名称 期货代码          日期     开盘     收盘     最高     最低    成交量           成交额  \
# 0     动力煤主力  ZCM  2015-05-18  440.0  437.6  440.2  437.6     64  2.806300e+06
# 1     动力煤主力  ZCM  2015-05-19  436.0  437.0  437.6  436.0      6  2.621000e+05
# 2     动力煤主力  ZCM  2015-05-20  436.8  435.8  437.0  434.8      8  3.487500e+05
# 3     动力煤主力  ZCM  2015-05-21  438.0  443.2  446.8  437.8     37  1.631850e+06
# 4     动力煤主力  ZCM  2015-05-22  439.2  441.4  443.8  439.2     34  1.502500e+06
# ...     ...  ...         ...    ...    ...    ...    ...    ...           ...
# 1519  动力煤主力  ZCM  2021-08-10  879.0  882.4  888.0  872.0  45324  3.990325e+09
# 1520  动力煤主力  ZCM  2021-08-11  885.6  896.0  908.8  882.2  49121  4.404189e+09
# 1521  动力煤主力  ZCM  2021-08-12  880.0  880.0  895.8  880.0  38732  3.435528e+09
# 1522  动力煤主力  ZCM  2021-08-13  764.0  778.6  781.0  758.2  62760  4.832520e+09
# 1523  动力煤主力  ZCM  2021-08-16  780.0  779.2  783.6  772.4  23153  1.798988e+09
#
#         振幅    涨跌幅    涨跌额  换手率
# 0     0.00   0.00    0.0  0.0
# 1     0.36  -0.32   -1.4  0.0
# 2     0.50  -0.23   -1.0  0.0
# 3     2.06   1.65    7.2  0.0
# 4     1.04   0.09    0.4  0.0
# ...    ...    ...    ...  ...
# 1519  1.82   0.14    1.2  0.0
# 1520  3.02   1.77   15.6  0.0
# 1521  1.76  -1.85  -16.6  0.0
# 1522  2.57 -12.22 -108.4  0.0
# 1523  1.45   1.19    9.2  0.0
#
# [1524 rows x 13 columns]

# %% [markdown]
# ### 获取多个期货历史 k 线数据

# %%
secids = ['115.ZCM','115.ZC109']
ef.futures.get_quote_history(secids)
# Out:
# Processing: 115.ZCM: 100%|██████████| 2/2 [00:00<00:00,  6.44it/s]
# {'115.ZC109':        期货名称   期货代码          日期     开盘     收盘     最高     最低    成交量  \
#  0    动力煤109  ZC109  2020-09-09  551.2  551.2  551.2  551.2      2
#  1    动力煤109  ZC109  2020-09-10  548.6  545.0  549.8  545.0      6
#  2    动力煤109  ZC109  2020-09-11  545.0  544.2  548.4  543.0      7
#  3    动力煤109  ZC109  2020-09-14  546.0  550.4  550.4  546.0      7
#  4    动力煤109  ZC109  2020-09-15  549.0  551.2  551.6  549.0     14
#  ..      ...    ...         ...    ...    ...    ...    ...    ...
#  222  动力煤109  ZC109  2021-08-10  879.0  882.4  888.0  872.0  45324
#  223  动力煤109  ZC109  2021-08-11  885.6  896.0  908.8  882.2  49121
#  224  动力煤109  ZC109  2021-08-12  880.0  880.0  895.8  880.0  38732
#  225  动力煤109  ZC109  2021-08-13  880.0  889.8  899.6  876.2  29412
#  226  动力煤109  ZC109  2021-08-16  882.6  888.2  890.0  882.6   7474
#
#                成交额    振幅   涨跌幅   涨跌额  换手率
#  0    1.102400e+05  0.00  0.00   0.0  0.0
#  1    3.289200e+05  0.87 -1.12  -6.2  0.0
#  2    3.815000e+05  0.99 -0.73  -4.0  0.0
#  3    3.843000e+05  0.81  0.99   5.4  0.0
#  4    7.705600e+05  0.47  0.40   2.2  0.0
#  ..            ...   ...   ...   ...  ...
#  222  3.990325e+09  1.82  0.14   1.2  0.0
#  223  4.404189e+09  3.02  1.77  15.6  0.0
#  224  3.435528e+09  1.76 -1.85 -16.6  0.0
#  225  2.611786e+09  2.64  0.32   2.8  0.0
#  226  6.624954e+08  0.83  0.02   0.2  0.0
#
#  [227 rows x 13 columns],
#  '115.ZCM':        期货名称 期货代码          日期     开盘     收盘     最高     最低    成交量           成交额  \
#  0     动力煤主力  ZCM  2015-05-18  440.0  437.6  440.2  437.6     64  2.806300e+06
#  1     动力煤主力  ZCM  2015-05-19  436.0  437.0  437.6  436.0      6  2.621000e+05
#  2     动力煤主力  ZCM  2015-05-20  436.8  435.8  437.0  434.8      8  3.487500e+05
#  3     动力煤主力  ZCM  2015-05-21  438.0  443.2  446.8  437.8     37  1.631850e+06
#  4     动力煤主力  ZCM  2015-05-22  439.2  441.4  443.8  439.2     34  1.502500e+06
#  ...     ...  ...         ...    ...    ...    ...    ...    ...           ...
#  1519  动力煤主力  ZCM  2021-08-10  879.0  882.4  888.0  872.0  45324  3.990325e+09
#  1520  动力煤主力  ZCM  2021-08-11  885.6  896.0  908.8  882.2  49121  4.404189e+09
#  1521  动力煤主力  ZCM  2021-08-12  880.0  880.0  895.8  880.0  38732  3.435528e+09
#  1522  动力煤主力  ZCM  2021-08-13  764.0  778.6  781.0  758.2  62760  4.832520e+09
#  1523  动力煤主力  ZCM  2021-08-16  780.0  779.2  783.6  772.4  23153  1.798988e+09
#
#          振幅    涨跌幅    涨跌额  换手率
#  0     0.00   0.00    0.0  0.0
#  1     0.36  -0.32   -1.4  0.0
#  2     0.50  -0.23   -1.0  0.0
#  3     2.06   1.65    7.2  0.0
#  4     1.04   0.09    0.4  0.0
#  ...    ...    ...    ...  ...
#  1519  1.82   0.14    1.2  0.0
#  1520  3.02   1.77   15.6  0.0
#  1521  1.76  -1.85  -16.6  0.0
#  1522  2.57 -12.22 -108.4  0.0
#  1523  1.45   1.19    9.2  0.0
#
#  [1524 rows x 13 columns]}

# %% [markdown]
# # 更多使用例子详见文档 [efinance-docs](https://efinance.readthedocs.io/)
